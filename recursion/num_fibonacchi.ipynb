# %%
def num_fibonacchi(n:int):
    if(n==0):
        return 0
    if(n==1):
        return 1
    return num_fibonacchi(n-1)+num_fibonacchi(n-2)

# %%
print(num_fibonacchi(5)) # exponential time complexity, computes same problem multiple times
# Out:
# 5
