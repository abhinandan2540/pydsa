# %%
def n_nums(n:int):
    if(n==0):
        return
    n_nums(n-1)
    print(n,end=" ")

# %%
n_nums(5) # time complexity: O(n)
# Out:
# 1 2 3 4 5

# %%
def n_nums(n:int):
    if(n==0):
        return
    print(n, end=" ")
    n_nums(n-1)

# %%
n_nums(5)
# Out:
# 5 4 3 2 1
